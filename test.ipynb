# %%
import pandas as pd

# %%
pd.read_excel("./Trip and visit WY24_25 Database.xlsx")
# Out:
# /home/vscode/.local/lib/python3.11/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#       S/N      Country Service             Type Departure Date Return Date  \
# 0       1     Thailand     ABC  Trip (Outgoing)     2024-05-01  2024-05-02
# 1       2       Brunei     DEF  Trip (Outgoing)     2024-05-29  2024-06-01
# 2       3       France     GHI  Trip (Outgoing)     2024-09-19  2024-09-20
# 3       4  Netherlands     JKL  Trip (Outgoing)     2024-04-12  2024-04-15
# 4       5        Kenya     MNO  Trip (Outgoing)     2024-10-20  2024-10-21
# ..    ...          ...     ...              ...            ...         ...
# 995   996          NaN     NaN              NaN            NaT         NaT
# 996   997          NaN     NaN              NaN            NaT         NaT
# 997   998          NaN     NaN              NaN            NaT         NaT
# ...
