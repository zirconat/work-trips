# %%
import pandas as pd

# %%
df = pd.read_excel("./Trip and visit WY24_25 Database.xlsx")
df
# Out:
# /home/vscode/.local/lib/python3.11/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#       S/N Departure Date Return Date             Type      Country     Status  \
# 0       1     2024-05-01  2024-05-02  Trip (Outgoing)     Thailand  Cancelled
# 1       2     2024-05-29  2024-06-01  Trip (Outgoing)       Brunei  Completed
# 2       3     2024-09-19  2024-09-20  Trip (Outgoing)       France    Planned
# 3       4     2024-04-12  2024-04-15  Trip (Outgoing)  Netherlands  Postponed
# 4       5     2024-10-20  2024-10-21  Trip (Outgoing)        Kenya  Scheduled
# ..    ...            ...         ...              ...          ...        ...
# 995   996            NaT         NaT              NaN          NaN        NaN
# 996   997            NaT         NaT              NaN          NaN        NaN
# 997   998            NaT         NaT              NaN          NaN        NaN
# ...

# %%
df.hide_index = True
df
# Out:
# Empty DataFrame
# Columns: [S/N, Departure Date, Return Date, Type, Country, Status, Level, Del Lead, Lead, Lead Dte, CG, Stakeholder, Service, Tier, Station, Confluence Link, AOR, Budgeted Amt, Utilised Amt, Remarks, Month, Year]
# Index: []
#
# [0 rows x 22 columns]
